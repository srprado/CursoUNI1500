# %%
import pandas as pd

# %%
df = pd.read_excel("dados.xlsx")
display(df)
# Out:
#                FAZENDA ESTADO            MUNICÍPIO  Nº ANIMAL      LOTE  \
# 0    Fazenda Marajoara     TO  Cariri do Tocantins   111113.0   LT01MRJ
# 1    Fazenda Marajoara     TO  Cariri do Tocantins   111114.0   LT02MRJ
# 2    Fazenda Marajoara     TO  Cariri do Tocantins   111115.0   LT03MRJ
# 3    Fazenda Marajoara     TO  Cariri do Tocantins   111116.0   LT04MRJ
# 4    Fazenda Marajoara     TO  Cariri do Tocantins   111117.0   LT05MRJ
# ..                 ...    ...                  ...        ...       ...
# 142  Fazenda Marajoara     TO  Cariri do Tocantins   111255.0  LT143MRJ
# 143  Fazenda Marajoara     TO  Cariri do Tocantins   111256.0  LT144MRJ
# 144  Fazenda Marajoara     TO  Cariri do Tocantins   111257.0  LT145MRJ
# 145  Fazenda Marajoara     TO  Cariri do Tocantins   111258.0  LT146MRJ
# 146  Fazenda Marajoara     TO  Cariri do Tocantins   111259.0  LT147MRJ
#
#          RAÇA          CATEGORIA   ECC  CICLICIDADE PROTOCOLO  ...       eCG  \
# ...

# %% [markdown]
# trocar os pontos por vírgula

# %%
df["ECC"] = df["ECC"].astype(str).str.replace(".", ",")

# %% [markdown]
# salvar o arquivo novamente

# %%
df.to_excel("dados_corrigidos.xlsx", index=False, engine="openpyxl")
